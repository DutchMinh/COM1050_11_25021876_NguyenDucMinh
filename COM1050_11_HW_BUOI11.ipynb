# %%
#w10a1
try:
  a,b = map(int,input().split())
  print(f"{(a/b):.2f}")
except ZeroDivisionError:
  print("Loi chia khong")
# Out:
# 0.80

# %%
#w10a2
try:
    lst = list(map(int,input().split()))
    n = int(input())
    print(lst[n])
except IndexError:
    print("Index out of range")

# %%
#w10a3
def happy_num(n):
    seen = set()
    while n != 1 and n not in seen:
        seen.add(n)
        n = sum(int(digit)**2 for digit in str(n))
    return n == 1
try:
    n = int(input())
    if happy_num(n):
        print('YES')
    else:
        print('NO')
except ValueError:
    print('Nhap 1 so nguyen duong')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 12
#      10 try:
#      11     n = int(input())
# ---> 12     if happy_num(n  ):
#      13         print('YES')
#      14     else:
#
# Cell In[21], line 7, in happy_num(n)
#       5     seen.add(n)
#       6     n1=0
# ----> 7     n1 += sum(int(digit)**2 for digit in str(n))
#       8     n = n1
#       9 return n == 1
#
# TypeError: 'int' object is not callable

# %%
#w10a4
try:
    a,b = map(int,input().split())
    sum = a + b
except ValueError:
    print('Nhap sai gia tri')
else:
    print(sum)
finally:
    print('Ket thuc chuong trinh')
# Out:
# 7
# Ket thuc chuong trinh

# %%
#w10a5
a = input().split(" ")
convert_a = []
for x in a:
    try:
        x = int(float(x))
        convert_a.append(x)
    except:
        print(f'Khong chuyen {x} sang int duoc')
print(convert_a)
# Out:
# [46464646464]

# %%
#w10a6
from math import*
try:
    n = int(input())
    print(f'{sqrt(n):.2f}')
except ValueError:
    print('So am')

# %%
#w10a7
try:
    age = int(input())
    if age < 0 :
        raise ValueError
except ValueError:
    print('Tuoi khong hop le')
else:
    print(2025 - age)
# Out:
# Tuoi khong hop le

# %%
#w10a8
try:
    file = input().lower()
    if file[-3:] not in ['txt','zip']:
        raise ValueError
except ValueError:
    print('File khong hop le')
else:
    print('Doc file thanh cong')

# %%
#w10a9
try:
    s = input()
    n = int(s)
    print(n)
except ValueError:
    print('Chuoi khong hop le')

# %%
#w10a10
try:
    a = list(map(int,input().split()))
    n=a[0]
    a = a[1:]
    if len(a) != len(set(a)):
        raise ValueError
    print(sum(a))
except ValueError:
    print('Mang khong hop le')

# %%
#w10a11
import re
try:
    t = int(input())
    for _ in range(t):
        s = input().strip()
        try:
            re.compile(s)
            print("Valid")
        except re.error:
            print("Invalid")
except EOFError:
    pass
