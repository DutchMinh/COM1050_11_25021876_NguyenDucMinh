# %%
#w6a1
lst1 = list(map(int, input().split()))
lst2 = []
seen = set()
for i in lst1:
    if i not in seen:
        lst2.append(i)
        seen.add(i)
print(lst2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 #w6a1
# ----> 2 lst1 = list(map(int, input().split()))
#       3 lst2 = []
#       4 seen = set()
#
# ValueError: invalid literal for int() with base 10: "'set'"

# %%
#w6a2
lst_num = list(map(int, input().split()))
total = 0
lst_sum = []
for i in lst_num:
    total += i
    lst_sum.append(total)
print(lst_sum)
# Out:
# [10, 5, 15]

# %%
#w6a3
tpl = tuple(map(int, input().split()))
k = int(input())
lst_num = list(tpl)
lst1 = lst_num[:k]
lst2 = lst_num[k:]
lst2.extend(lst1)
print(tuple(lst2))
# Out:
# (3, 4, 5, 1, 2)

# %%
#w6a4
s = input()
pairs = s.split()
dict = {}
for i in pairs:
    key, value = i.split(':')
    dict.setdefault(key, []).append(value)
print(dict)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %%
#w6a5
lst = list(map(int, input().split()))
dict = {
    'positives': 0,
    'negatives': 0,
    'zeros': 0
}
for i in lst:
    if i > 0:
        dict['positives'] += 1
    elif i < 0:
        dict['negatives'] += 1
    else:
        dict['zeros'] += 1
print(dict)
# Out:
# {'positives': 2, 'negatives': 2, 'zeros': 3}

# %%
#w6a6
lst = list(map(int, input().split()))
print(sum(lst))
# Out:
# 10

# %%
#w6a7
tpl = tuple(map(str, input().split()))
a, b = (tpl[0], tpl[-1])
print(a, b, tpl[::-1])
# Out:
# 5 4 ('4', '1', '7', '2', '8', '5')

# %%
#w6a8
s = input()
words = s.split()
dict = {}
for i in words:
    if i not in dict:
        dict[i] = 1
    else:
        dict[i] += 1
print(dict)
# Out:
# {'1': 3, '2': 2, '3': 1}

# %%
#w6a9
s1 = input()
s2 = input()
s_general = 
dict = {}
for i in

# %%
lst = [3,4,6,1,7,3,5,6,4]
lst_sort = []
for i in lst:
    if i not in lst_sort:
        lst_sort.append(i)
print(lst_sort)
# Out:
# [3, 4, 6, 1, 7, 5]

# %%
s1 = input()
s2 = input()
s_general = s1 + s2
pairs = s_general.split()
remove_special = {'{', '}'}
s_general = [x for x in s_general if x not in remove_special]
print(s_general)
# Out:
# ['a', ':', '1', 'a', ':', '2']

# %%
lst = ['a:1']
lst1 = ['a:2']
dict = {}
for i in lst + lst1:
    key, value = i.split(':')
    dict.setdefault(key, []).append(int(value))
print(dict)
# Out:
# {'a': [1, 2]}
